# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"D:\Data Analytics\datasets\cgpa\cgpa.csv")

# %%
df.head()
# Out:
#    rollno      cgpa  rank
# 0       1  5.215008  9000
# 1       2  6.161833  9001
# 2       3  8.301801  9002
# 3       4  6.889414  9003
# 4       5  8.393946  9004

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 3 columns):
# rollno    500000 non-null int64
# cgpa      500000 non-null float64
# rank      500000 non-null int64
# dtypes: float64(1), int64(2)
# memory usage: 11.4 MB

# %%
#writing function to change cgpa into grade
def cgpa_to_grade(item):
    cgpa=item.loc['cgpa']
    if cgpa>8:
        return 'A'
    else:
        return 'B'

# %%
# %%time
df['grade']=df.apply(cgpa_to_grade,axis=1)
df['grade'].value_counts()
# Out:
# Wall time: 20.3 s

# %%
def cgpa_to_grade_2(item):
    if item >= 8 and item <10:
        return 'A'
    elif item>=6 and item<8:
        return 'B'
    elif item>=4 and item<6:
        return 'B'
    else:
        return 'D'

# %%
# %%time
df['grade2']=df['cgpa'].apply(cgpa_to_grade_2)
df['grade2'].value_counts()
# Out:
# Wall time: 295 ms

# %%
df.tail(20)
# Out:
#         rollno      cgpa    rank grade grade2
# 499980  499981  9.019354  508980     A      A
# 499981  499982  7.199021  508981     B      B
# 499982  499983  5.314654  508982     B      B
# 499983  499984  8.823959  508983     A      A
# 499984  499985  9.570014  508984     A      A
# 499985  499986  7.610885  508985     B      B
# 499986  499987  6.466133  508986     B      B
# 499987  499988  5.588674  508987     B      B
# 499988  499989  8.681556  508988     A      A
# 499989  499990  8.504246  508989     A      A
# 499990  499991  8.841961  508990     A      A
# 499991  499992  6.136499  508991     B      B
# 499992  499993  7.096307  508992     B      B
# 499993  499994  7.769875  508993     B      B
# 499994  499995  5.747173  508994     B      B
# 499995  499996  9.387890  508995     A      A
# 499996  499997  9.094913  508996     A      A
# 499997  499998  8.430407  508997     A      A
# 499998  499999  7.329542  508998     B      B
# ...

# %%
df_2=pd.read_csv('D:/Data Analytics/datasets/Blood Donation/training.csv')

# %%
df_2.head()
# Out:
#    Unnamed: 0  Months since Last Donation  Number of Donations  \
# 0         619                           2                   50
# 1         664                           0                   13
# 2         441                           1                   16
# 3         160                           2                   20
# 4         358                           1                   24
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
#
#    Made Donation in March 2007
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            0

# %%
df_2.rename(columns={'Unnamed: 0':'id'}, inplace=True)

# %%
df_2.head()
# Out:
#     id  Months since Last Donation  Number of Donations  \
# 0  619                           2                   50
# 1  664                           0                   13
# 2  441                           1                   16
# 3  160                           2                   20
# 4  358                           1                   24
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
#
#    Made Donation in March 2007
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            0

# %%
def id_contains(item):
    x= str(item)
    if '6' in x:
        a='contains 6'
    else:
        a = 'no 6'
    return a

# %%
df_2['out']=df_2['id'].apply(id_contains)

# %%
df_2.head()
# Out:
#     id  Months since Last Donation  Number of Donations  \
# 0  619                           2                   50
# 1  664                           0                   13
# 2  441                           1                   16
# 3  160                           2                   20
# 4  358                           1                   24
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
#
#    Made Donation in March 2007         out
# 0                            1  contains 6
# 1                            1  contains 6
# 2                            1        no 6
# 3                            1  contains 6
# 4                            0        no 6

# %%
def out_contains(item):
    if 'con' in item or 'tain' in item:
        a='got you'
    else:
        a = 'got you too'
    return a

# %%
df_2['out2']=df_2['out'].apply(out_contains)

# %%
df_2.head()
# Out:
#     id  Months since Last Donation  Number of Donations  \
# 0  619                           2                   50
# 1  664                           0                   13
# 2  441                           1                   16
# 3  160                           2                   20
# 4  358                           1                   24
#
#    Total Volume Donated (c.c.)  Months since First Donation  \
# 0                        12500                           98
# 1                         3250                           28
# 2                         4000                           35
# 3                         5000                           45
# 4                         6000                           77
#
#    Made Donation in March 2007         out         out2
# 0                            1  contains 6      got you
# 1                            1  contains 6      got you
# 2                            1        no 6  got you too
# ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 8 columns):
# id                             576 non-null int64
# Months since Last Donation     576 non-null int64
# Number of Donations            576 non-null int64
# Total Volume Donated (c.c.)    576 non-null int64
# Months since First Donation    576 non-null int64
# Made Donation in March 2007    576 non-null int64
# out                            576 non-null object
# out2                           576 non-null object
# dtypes: int64(6), object(2)
# memory usage: 36.1+ KB

# %%
import numpy as np
from datetime import datetime

# %%
def float_to_date(date):
    if np.isnan(date):
        return np.nan
    
    date=str(int(date))
    year=date[-4:]
    if int(year)<1900: return np.nan
    day=date[-6:-4]
    if day==np.nan or day=='': day='01'
        
    month=date[0:-6]
    if month=='': month='01'
    date=datetime(int(year),int(month),int(day))
    return date

# %%
float_to_date(1957.0)
# Out:
# datetime.datetime(1957, 1, 1, 0, 0)

# %%
DOB=pd.Series([11111911,1957,np.NaN,1957.0,315])

# %%
DOB.apply(float_to_date)
# Out:
# 0   1911-11-11
# 1   1957-01-01
# 2          NaT
# 3   1957-01-01
# 4          NaT
# dtype: datetime64[ns]

# %%
df
# Out:
#         rollno      cgpa    rank grade grade2
# 0            1  5.215008    9000     B      B
# 1            2  6.161833    9001     B      B
# 2            3  8.301801    9002     A      A
# 3            4  6.889414    9003     B      B
# 4            5  8.393946    9004     A      A
# 5            6  5.460920    9005     B      B
# 6            7  9.208346    9006     A      A
# 7            8  6.419625    9007     B      B
# 8            9  8.987262    9008     A      A
# 9           10  6.580631    9009     B      B
# 10          11  6.497459    9010     B      B
# 11          12  9.184521    9011     A      A
# 12          13  8.290301    9012     A      A
# 13          14  5.076682    9013     B      B
# 14          15  9.125899    9014     A      A
# 15          16  5.338948    9015     B      B
# 16          17  7.560300    9016     B      B
# 17          18  8.671263    9017     A      A
# 18          19  8.600598    9018     A      A
# ...

# %%
df1=df.groupby(['cgpa'],as_index=False).agg({
                                            'rollno':{'count','mean'},
                                            'rank':{'min','mean'}
                                            
                                            })

# %%
df1.add_suffix('_count').reset_index()
# Out:
#          index cgpa_count rollno_count            rank_count
#                    _count  count_count mean_count  min_count mean_count
# 0            0   5.000001            1      68259      77258      77258
# 1            1   5.000075            1     421676     430675     430675
# 2            2   5.000083            1     392859     401858     401858
# 3            3   5.000088            1     488445     497444     497444
# 4            4   5.000091            1     488134     497133     497133
# 5            5   5.000106            1     386330     395329     395329
# 6            6   5.000111            1      76204      85203      85203
# 7            7   5.000126            1     341776     350775     350775
# 8            8   5.000127            1     371838     380837     380837
# 9            9   5.000131            1     235768     244767     244767
# 10          10   5.000133            1     436281     445280     445280
# ...

# %%
df.head()
# Out:
#    rollno      cgpa  rank grade grade2
# 0       1  5.215008  9000     B      B
# 1       2  6.161833  9001     B      B
# 2       3  8.301801  9002     A      A
# 3       4  6.889414  9003     B      B
# 4       5  8.393946  9004     A      A

# %%
bins=[1,7,9]
df['cgpa_bin']=pd.cut(df['cgpa'],bins)

# %%
df['cgpa_bin'].value_counts()
# Out:
# (1, 7]    200796
# (7, 9]    199401
# Name: cgpa_bin, dtype: int64

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of         rollno      cgpa    rank grade grade2                rank_bin  \
# 0            1  5.215008    9000     B      B  (8500.001, 175666.333]
# 1            2  6.161833    9001     B      B  (8500.001, 175666.333]
# 2            3  8.301801    9002     A      A  (8500.001, 175666.333]
# 3            4  6.889414    9003     B      B  (8500.001, 175666.333]
# 4            5  8.393946    9004     A      A  (8500.001, 175666.333]
# 5            6  5.460920    9005     B      B  (8500.001, 175666.333]
# 6            7  9.208346    9006     A      A  (8500.001, 175666.333]
# 7            8  6.419625    9007     B      B  (8500.001, 175666.333]
# 8            9  8.987262    9008     A      A  (8500.001, 175666.333]
# 9           10  6.580631    9009     B      B  (8500.001, 175666.333]
# 10          11  6.497459    9010     B      B  (8500.001, 175666.333]
# 11          12  9.184521    9011     A      A  (8500.001, 175666.333]
# ...

# %%
import numpy as np
from scipy.optimize import minimize
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-181-a80a466f82a4> in <module>
#       1 import numpy as np
#       2 from scipy.optimize import minimize
# ----> 3 from scipy.optimize import maximize
#
# ImportError: cannot import name 'maximize' from 'scipy.optimize' (C:\Users\sameer\Anaconda3\lib\site-packages\scipy\optimize\__init__.py)

# %%
print(avg_value(7))
# Out:
# nan

# %%
df['cgpa'][df['cgpa_bin']==]
# Out:
# Series([], Name: cgpa, dtype: float64)

# %%
df['cgpa_bin'].head()
# Out:
# 0    (1, 7]
# 1    (1, 7]
# 2    (7, 9]
# 3    (1, 7]
# 4    (7, 9]
# Name: cgpa_bin, dtype: category
# Categories (2, interval[int64]): [(1, 7] < (7, 9]]

# %%
df['Cgpa_bin_2'] = pd.arrays.IntervalArray(df['cgpa_bin'] )

# %%
table=pd.pivot_table(df,values='cgpa',index='Cgpa_bin_2',aggfunc='mean').reset_index()

# %%
table
# Out:
#    Cgpa_bin_2      cgpa
# 0  (1.0, 7.0]  6.000451
# 1  (7.0, 9.0]  7.999539

# %%
bins=[0,6,9]
df['cgpa_bin']=pd.cut(df['cgpa'],bins)
df['cgpa_bin'].value_counts()
df['Cgpa_bin_2'] = pd.arrays.IntervalArray(df['cgpa_bin'] )
table=pd.pivot_table(df,values='cgpa',index='Cgpa_bin_2',aggfunc='mean').reset_index()
table
#diff=table.loc[1,'cgpa']-table.loc[0,'cgpa']
#diff
# Out:
#    Cgpa_bin_2      cgpa
# 0  (0.0, 6.0]  5.499796
# 1  (6.0, 9.0]  7.497691

# %%
def objective(bins):
    
    df['cgpa_bin']=pd.cut(df['cgpa'],bins)
    df['Cgpa_bin_2'] = pd.arrays.IntervalArray(df['cgpa_bin'] )
    table=pd.pivot_table(df,values='cgpa',index='Cgpa_bin_2',aggfunc='mean').reset_index()
    diff=table.loc[1,'cgpa']-table.loc[0,'cgpa']
    return diff

# %%
objective([0,6,9])
# Out:
# 1.9978945151100085

# %%
def constraint1(bins):
    return bins[1]-bins[0]

# %%
def constraint2(bins):
    return bins[2]-bins[1]

# %%
def constraint3(bins):
    return bins[1]-5

# %%
# initial guesses
n = 3
bins0 = np.zeros(n)
bins0[0] = 1
bins0[1] = 6
bins0[2]=9
bins0
# Out:
# array([1., 6., 9.])

# %%
# show initial objective
print('Initial SSE Objective: ' + str(objective(bins0)))
# Out:
# Initial SSE Objective: 1.9978945151100085

# %%
# optimize
b = (1.0,10.0)
bnds = (b, b, b)
con1 = {'type': 'ineq', 'fun': constraint1}
con2 = {'type': 'ineq', 'fun': constraint2}
con3 = {'type': 'ineq', 'fun': constraint3}

cons = ([con1,con2,con3])
solution = minimize(objective,bins0,method='SLSQP',
                    bounds=bnds,constraints=cons)
bins=solution.bins
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in __getattr__(self, name)
#     113         try:
# --> 114             return self[name]
#     115         except KeyError:
#
# KeyError: 'bins'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-179-91eb8c6afff0> in <module>
#       9 solution = minimize(objective,bins0,method='SLSQP',
#      10                     bounds=bnds,constraints=cons)
# ---> 11 bins=solution.bins
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in __getattr__(self, name)
#     114             return self[name]
#     115         except KeyError:
# --> 116             raise AttributeError(name)
#     117
#     118     __setattr__ = dict.__setitem__
#
# ...

# %%
print(bins)
# Out:
# [0, 6, 9]

# %%
# show final objective
print('Final SSE Objective: ' + str(objective(bins2)))

# print solution
print('Solution')
print('bin1 = ' + str(bins2[0]))
print('bin2 = ' + str(bins2[1]))
print('bin3 = ' + str(bins2[2]))

# %%
objective([1.0.7.0,9.0])
# Out:
#   File "<ipython-input-137-623c8b974213>", line 1
#     objective([1.0.7.0,9.0])
#                    ^
# SyntaxError: invalid syntax

# %%
import numpy as np
from scipy.optimize import minimize

def objective(x):
    return x[0]*x[3]*(x[0]+x[1]+x[2])+x[2]

def constraint1(x):
    return x[0]*x[1]*x[2]*x[3]-25.0

def constraint2(x):
    sum_eq = 40.0
    for i in range(4):
        sum_eq = sum_eq - x[i]**2
    return sum_eq

# initial guesses
n = 4
x0 = np.zeros(n)
x0[0] = 1.0
x0[1] = 5.0
x0[2] = 5.0
x0[3] = 1.0

# show initial objective
print('Initial SSE Objective: ' + str(objective(x0)))

# optimize
b = (1.0,5.0)
bnds = (b, b, b, b)
con1 = {'type': 'ineq', 'fun': constraint1}
con2 = {'type': 'eq', 'fun': constraint2}
cons = ([con1,con2])
solution = minimize(objective,x0,method='SLSQP',\
                    bounds=bnds,constraints=cons)
x = solution.x

# show final objective
print('Final SSE Objective: ' + str(objective(x)))

# print solution
print('Solution')
print('x1 = ' + str(x[0]))
print('x2 = ' + str(x[1]))
print('x3 = ' + str(x[2]))
print('x4 = ' + str(x[3]))
# Out:
# Initial SSE Objective: 16.0
# Final SSE Objective: 17.01401724563517
# Solution
# x1 = 1.0
# x2 = 4.742996096883977
# x3 = 3.8211546234095715
# x4 = 1.379407645075325
